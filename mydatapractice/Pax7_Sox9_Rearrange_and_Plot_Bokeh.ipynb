# %%
import numpy as np
import pandas as pd

# Import Bokeh modules for interactive plotting
import bokeh.io
import bokeh.models
import bokeh.palettes
import bokeh.plotting

import skimage
import skimage.io


import bootcamp_utils

# Display graphics in this notebook
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="34bc65ed-4586-4c2c-b5bb-38c8beb2e2f5">Loading BokehJS ...</span>
#     </div>

# %%
ls
# Out:
# MyData.ipynb                        notebook.tex
# Pax7_Sox9_Rearrange_and_Plot.ipynb  output_8_0.png
# Pax7_and_Sox9_Counts.ipynb          output_9_0.png
# SMPD3CountsToTidy.xlsx              section_means_ratio.csv
# SMPD3_Quants.xlsx                   smpd3_crispr_tcflef.csv
# TCFLef_SMPD3_CRISPR.ipynb           smpd3_quants.csv

# %%
df = pd.read_csv('melted2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Embryo      stain  cells      ECDF
# 0           0       1  cntl pax7   36.8  0.571429
# 1           1       2  cntl pax7   46.4  0.857143
# 2           2       3  cntl pax7   34.2  0.285714
# 3           3       5  cntl pax7   73.6  1.000000
# 4           4       6  cntl pax7   34.8  0.428571

# %%
bokeh.io.show(bootcamp_utils.bokeh_ecdf_collection(df, 'stain', 'cells', 
                        palette=['#1f77b4', '#2ca02c', '#ff7f0e', '#d62728'],
                        size=6, alpha=0.7))
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="59c6ffd2-b060-47a3-b751-7467c2349f54"></div>
# </div>

# %%
bokeh.io.show(bootcamp_utils.bokeh_jitter(df, 'stain', 'cells', 
                        palette=['#1f77b4', '#2ca02c', '#ff7f0e', '#d62728'], 
                        jitter_width=0.4, alpha=0.7, size=7))
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="bc6bdc3a-2edb-4a2e-905b-66c85c33972a"></div>
# </div>
