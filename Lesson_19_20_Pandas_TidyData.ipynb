# %%
import pandas as pd
import numpy as np

# %%
# !head data/gfmt_sleep.csv
# Out:
# ﻿participant number,gender,age,correct hit percentage,correct reject percentage,percent correct,confidence when correct hit,confidence incorrect hit,confidence correct reject,confidence incorrect reject,confidence when correct,confidence when incorrect,sci,psqi,ess
# 8,f,39,65,80,72.5,91,90,93,83.5,93,90,9,13,2
# 16,m,42,90,90,90,75.5,55.5,70.5,50,75,50,4,11,7
# 18,f,31,90,95,92.5,89.5,90,86,81,89,88,10,9,3
# 22,f,35,100,75,87.5,89.5,*,71,80,88,80,13,8,20
# 27,f,74,60,65,62.5,68.5,49,61,49,65,49,13,9,12
# 28,f,61,80,20,50,71,63,31,72.5,64.5,70.5,15,14,2
# 30,m,32,90,75,82.5,67,56.5,66,65,66,64,16,9,3
# 33,m,62,45,90,67.5,54,37,65,81.5,62,61,14,9,9
# 34,f,33,80,100,90,70.5,76.5,64.5,*,68,76.5,14,12,10

# %%
#store file in variable called 'df' for 'dataframe'
df = pd.read_csv('data/gfmt_sleep.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#look at the docstring to figure out what arguments to read in
pd.read_csv?
# Out:
# Signature: pd.read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, skipfooter=0, doublequote=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
# Docstring:
# Read CSV (comma-separated) file into DataFrame
#
# Also supports optionally iterating or breaking of the file
# ...

# %%
#if we call df, it shows the first 30 rows, a break, and the last 30 rows
#if we use .head() it will show just the first five
df.head(10)
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
# 5                  28      f   61                      80
# 6                  30      m   32                      90
# 7                  33      m   62                      45
# 8                  34      f   33                      80
# 9                  35      f   53                     100
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# ...

# %%
df['sci'].head(10)
# Out:
# 0     9
# 1     4
# 2    10
# 3    13
# 4    13
# 5    15
# 6    16
# 7    14
# 8    14
# 9    14
# Name: sci, dtype: int64

# %%
df['percent correct']
# Out:
# 0       72.5
# 1       90.0
# 2       92.5
# 3       87.5
# 4       62.5
# 5       50.0
# 6       82.5
# 7       67.5
# 8       90.0
# 9       75.0
# 10      62.5
# 11      95.0
# 12      80.0
# 13      80.0
# 14      65.0
# 15      70.0
# 16      70.0
# 17      80.0
# 18      85.0
# 19      75.0
# 20      70.0
# 21      97.5
# 22      87.5
# 23      45.0
# 24      70.0
# 25      72.5
# 26      85.0
# 27      75.0
# 28      67.5
# 29      95.0
#        ...
# 72      87.5
# 73      97.5
# 74      92.5
# 75     100.0
# 76      60.0
# 77      95.0
# 78      77.5
# 79      77.5
# 80      82.5
# 81      40.0
# 82      87.5
# 83      85.0
# 84      87.5
# 85      77.5
# 86      62.5
# 87      72.5
# 88      85.0
# 89      92.5
# 90      85.0
# 91      72.5
# 92      90.0
# 93      90.0
# 94      55.0
# 95      87.5
# 96      60.0
# 97      77.5
# 98      87.5
# 99      75.0
# 100     70.0
# 101     62.5
# Name: percent correct, Length: 102, dtype: float64

# %%
#this is a way to index, but don't do it
df['percent correct'][4]
# Out:
# 62.5

# %%
#do this indexing instead
df.loc[4, 'percent correct']
# Out:
# 62.5

# %%
#boolean indexing
#want to pull out everything from participant number 22, which doesn't match the row indexing
df.loc[df['participant number'] == 22, 'percent correct']
#it asks 'where the participant number value is equal to 22', call 'percent correct'
# Out:
# 3    87.5
# Name: percent correct, dtype: float64

# %%
#look at this
df['participant number'] == 22
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 72     False
# 73     False
# 74     False
# 75     False
# 76     False
# 77     False
# 78     False
# 79     False
# 80     False
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# Name: participant number, Length: 102, dtype: bool

# %%
#while colon not necessary, leaving it there will tell future me that i intentionally want the whole record
df.loc[df['participant number'] == 22, :]
# Out:
#    participant number gender  age  correct hit percentage  \
# 3                  22      f   35                     100
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 3                         75             87.5                         89.5
#
#   confidence incorrect hit  confidence correct reject  \
# 3                        *                       71.0
#
#   confidence incorrect reject  confidence when correct  \
# 3                          80                     88.0
#
#   confidence when incorrect  sci  psqi  ess
# 3                        80   13     8   20

# %%
df.loc[df['correct hit percentage'] == 100, 'participant number']
# Out:
# 3      22
# 9      35
# 16     76
# 18     78
# 19     80
# 21     90
# 22     93
# 24    101
# 33     10
# 40     19
# 45     25
# 54     42
# 70     62
# 73     65
# 75     67
# 89     86
# 92     91
# Name: participant number, dtype: int64

# %%
#when working with multiple boolean indecies, you put each test in parentheses, & for and, | for or, 
df.loc[(df['age'] < 21) & (df['gender'] == 'f'), :]
# Out:
#     participant number gender  age  correct hit percentage  \
# 27                   3      f   16                      70
# 29                   5      f   18                      90
# 66                  58      f   16                      85
# 79                  72      f   18                      80
# 88                  85      f   18                      85
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 27                         80             75.0                         70.0
# 29                        100             95.0                         76.5
# 66                         85             85.0                         55.0
# 79                         75             77.5                         67.5
# 88                         85             85.0                         93.0
#
#    confidence incorrect hit  confidence correct reject  \
# 27                       57                       54.0
# ...

# %%
#or we can assign this subset of data to new dataframe
df_female_minor = df.loc[(df['age'] < 21) & (df['gender'] == 'f'), :]

# %%
df_female_minor
# Out:
#     participant number gender  age  correct hit percentage  \
# 27                   3      f   16                      70
# 29                   5      f   18                      90
# 66                  58      f   16                      85
# 79                  72      f   18                      80
# 88                  85      f   18                      85
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 27                         80             75.0                         70.0
# 29                        100             95.0                         76.5
# 66                         85             85.0                         55.0
# 79                         75             77.5                         67.5
# 88                         85             85.0                         93.0
#
#    confidence incorrect hit  confidence correct reject  \
# 27                       57                       54.0
# ...

# %%
#all females over 30, with greater than 85% correct
df.loc[(df['age'] > 30) & (df['gender'] == 'f') & (df['percent correct'] > 90)]
# Out:
#     participant number gender  age  correct hit percentage  \
# 2                   18      f   31                      90
# 11                  41      f   36                      90
# 31                   7      f   38                      90
# 40                  19      f   45                     100
# 70                  62      f   42                     100
# 73                  65      f   31                     100
# 74                  66      f   44                      90
# 77                  69      f   47                      90
# 89                  86      f   31                     100
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 2                          95             92.5                         89.5
# 11                        100             95.0                         76.5
# 31                         95             92.5                         77.0
# ...

# %%
#can store out the boolean operators

inds = (df['age'] > 30) & (df['gender'] == 'f') & (df['percent correct'] > 90)

df.loc[inds, :]
# Out:
#     participant number gender  age  correct hit percentage  \
# 2                   18      f   31                      90
# 11                  41      f   36                      90
# 31                   7      f   38                      90
# 40                  19      f   45                     100
# 70                  62      f   42                     100
# 73                  65      f   31                     100
# 74                  66      f   44                      90
# 77                  69      f   47                      90
# 89                  86      f   31                     100
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 2                          95             92.5                         89.5
# 11                        100             95.0                         76.5
# 31                         95             92.5                         77.0
# ...

# %%
#cutoff to say that someone is insomniac
df['sci'] <= 16
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 72     False
# 73     False
# 74     False
# 75     False
# 76     False
# 77     False
# 78     False
# 79     False
# 80     False
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# Name: sci, Length: 102, dtype: bool

# %%
#define a new column in the dataframe that will populate with the results of this procedure
#takes a procedural code (the for loop to determine if insomniac), and makes it declarative
df['insomnia'] = df['sci'] <= 16

# %%
df.head()
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#   confidence incorrect hit  confidence correct reject  \
# 0                       90                       93.0
# ...

# %%
df.dtypes
# Out:
# participant number               int64
# gender                          object
# age                              int64
# correct hit percentage           int64
# correct reject percentage        int64
# percent correct                float64
# confidence when correct hit    float64
# confidence incorrect hit        object
# confidence correct reject      float64
# confidence incorrect reject     object
# confidence when correct        float64
# confidence when incorrect       object
# sci                              int64
# psqi                             int64
# ess                              int64
# insomnia                          bool
# dtype: object

# %%
df.describe()
# Out:
#        participant number         age  correct hit percentage  \
# count          102.000000  102.000000              102.000000
# mean            52.049020   37.921569               83.088235
# std             30.020909   14.029450               15.091210
# min              1.000000   16.000000               35.000000
# 25%             26.250000   26.500000               75.000000
# 50%             52.500000   36.500000               90.000000
# 75%             77.750000   45.000000               95.000000
# max            103.000000   74.000000              100.000000
#
#        correct reject percentage  percent correct  \
# count                 102.000000       102.000000
# mean                   77.205882        80.147059
# std                    17.569854        12.047881
# min                    20.000000        40.000000
# 25%                    70.000000        72.500000
# 50%                    80.000000        83.750000
# 75%                    90.000000        87.500000
# ...

# %%
df.loc[df['insomnia'] == True, :].describe()
# Out:
#        participant number        age  correct hit percentage  \
# count           25.000000  25.000000               25.000000
# mean            53.400000  40.320000               82.000000
# std             29.219001  12.915495               18.314384
# min              8.000000  24.000000               40.000000
# 25%             30.000000  31.000000               70.000000
# 50%             46.000000  39.000000               90.000000
# 75%             78.000000  44.000000              100.000000
# max            101.000000  74.000000              100.000000
#
#        correct reject percentage  percent correct  \
# count                   25.00000        25.000000
# mean                    70.20000        76.100000
# std                     23.33988        13.347909
# min                     20.00000        45.000000
# 25%                     55.00000        70.000000
# 50%                     75.00000        75.000000
# 75%                     90.00000        87.500000
# ...

# %%
#we had a problem with the * representing no data point, but the descriptive stats counted them as a value
#if we look at the docstring for pd.read_csv, we see there is a na_values = None, which will insert the * and that counts as a datapoint now
#instead, this will make the dataframe with NaN in those places, which will not factor into descriptive stats

df = pd.read_csv('data/gfmt_sleep.csv', na_values = '*')

# %%
df.head(10)
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
# 5                  28      f   61                      80
# 6                  30      m   32                      90
# 7                  33      m   62                      45
# 8                  34      f   33                      80
# 9                  35      f   53                     100
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# ...

# %%
df.count()
# Out:
# participant number             102
# gender                         102
# age                            102
# correct hit percentage         102
# correct reject percentage      102
# percent correct                102
# confidence when correct hit    102
# confidence incorrect hit        84
# confidence correct reject      102
# confidence incorrect reject     93
# confidence when correct        102
# confidence when incorrect       99
# sci                            102
# psqi                           102
# ess                            102
# dtype: int64

# %%
df.head()
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#    confidence incorrect hit  confidence correct reject  \
# 0                      90.0                       93.0
# ...

# %%
df['insomnia'] = df['sci'] <= 16

# %%
df.head()
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#    confidence incorrect hit  confidence correct reject  \
# 0                      90.0                       93.0
# ...

# %% [markdown]
# #tidydata = each variable is a column, each observation is a row
# #always keep data in a tidydata format, because it will make all sorts of analyses easy-peasy!
# #get out of the habit of trying to have "Pax7" superheader over "Control" and "Experimenta" columns
#     #instead, go with Pax7 control and Pax7 experimental

# %% [markdown]
# split, apply, combine occurs over and over and over
# you're taking a split from your dataframe (pull out entries you want), apply is computing what you want from that, and combine will then put them back together

# %%
#this will group dataframe by the column insomnia, and the number of groups 
#are defined by the number of values found in column 'insomnia'
grouped = df.groupby('insomnia')
    #groupby is our split step

# %%
grouped.median()
    #median is our apply AND combine
# Out:
#           participant number  age  correct hit percentage  \
# insomnia
# False                     54   36                      90
# True                      46   39                      90
#
#           correct reject percentage  percent correct  \
# insomnia
# False                            80             85.0
# True                             75             75.0
#
#           confidence when correct hit  confidence incorrect hit  \
# insomnia
# False                            74.5                      55.5
# True                             76.5                      72.0
#
#           confidence correct reject  confidence incorrect reject  \
# insomnia
# False                          71.5                         59.0
# True                           71.0                         68.5
#
#           confidence when correct  confidence when incorrect  sci  psqi  ess
# insomnia
# False                        75.0                      59.25   26     4    6
# ...

# %%
grouped['percent correct'].median()
# Out:
# insomnia
# False    85.0
# True     75.0
# Name: percent correct, dtype: float64

# %%
grouped.median()
# Out:
#           participant number  age  correct hit percentage  \
# insomnia
# False                     54   36                      90
# True                      46   39                      90
#
#           correct reject percentage  percent correct  \
# insomnia
# False                            80             85.0
# True                             75             75.0
#
#           confidence when correct hit  confidence incorrect hit  \
# insomnia
# False                            74.5                      55.5
# True                             76.5                      72.0
#
#           confidence correct reject  confidence incorrect reject  \
# insomnia
# False                          71.5                         59.0
# True                           71.0                         68.5
#
#           confidence when correct  confidence when incorrect  sci  psqi  ess
# insomnia
# False                        75.0                      59.25   26     4    6
# ...

# %%
grouped.median().reset_index()
# Out:
#    insomnia  participant number  age  correct hit percentage  \
# 0     False                  54   36                      90
# 1      True                  46   39                      90
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             85.0                         74.5
# 1                         75             75.0                         76.5
#
#    confidence incorrect hit  confidence correct reject  \
# 0                      55.5                       71.5
# 1                      72.0                       71.0
#
#    confidence incorrect reject  confidence when correct  \
# 0                         59.0                     75.0
# 1                         68.5                     77.0
#
#    confidence when incorrect  sci  psqi  ess
# 0                      59.25   26     4    6
# 1                      65.00   14     9    7

# %%
grouped2 = df.groupby(['gender', 'insomnia'])

# %%
grouped2.median().reset_index()
# Out:
#   gender  insomnia  participant number   age  correct hit percentage  \
# 0      f     False                58.0  36.0                    85.0
# 1      f      True                46.0  39.0                    80.0
# 2      m     False                41.0  38.5                    90.0
# 3      m      True                55.5  37.0                    95.0
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                       80.0            85.00                        74.00
# 1                       75.0            72.50                        76.50
# 2                       80.0            82.50                        76.00
# 3                       82.5            83.75                        83.75
#
#    confidence incorrect hit  confidence correct reject  \
# 0                     55.00                      70.50
# 1                     73.75                      71.00
# 2                     57.75                      74.25
# ...

# %%
#define our own function to deal with things not present in pandas
def coeff_of_var(data):
    return np.std(data) / np.mean(data)

# %%
grouped = df.groupby('insomnia')

# %%
grouped.median()
# Out:
#           participant number  age  correct hit percentage  \
# insomnia
# False                     54   36                      90
# True                      46   39                      90
#
#           correct reject percentage  percent correct  \
# insomnia
# False                            80             85.0
# True                             75             75.0
#
#           confidence when correct hit  confidence incorrect hit  \
# insomnia
# False                            74.5                      55.5
# True                             76.5                      72.0
#
#           confidence correct reject  confidence incorrect reject  \
# insomnia
# False                          71.5                         59.0
# True                           71.0                         68.5
#
#           confidence when correct  confidence when incorrect  sci  psqi  ess
# insomnia
# False                        75.0                      59.25   26     4    6
# ...

# %%
grouped.agg(coeff_of_var).reset_index()
# Out:
#    insomnia  participant number       age  correct hit percentage  \
# 0     False            0.586191  0.384262                0.166784
# 1      True            0.536117  0.313853                0.218834
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                   0.184061         0.138785                     0.195978
# 1                   0.325760         0.171856                     0.156219
#
#    confidence incorrect hit  confidence correct reject  \
# 0                  0.350286                   0.204312
# 1                  0.225440                   0.222827
#
#    confidence incorrect reject  confidence when correct  \
# 0                     0.298216                 0.187304
# 1                     0.211512                 0.160061
#
#    confidence when incorrect       sci      psqi       ess
# 0                   0.262509  0.175245  0.577869  0.571566
# 1                   0.197484  0.381907  0.299741  0.681514

# %%
#transformations
df['rank grouped by insomnia'] = (grouped['percent correct']
                                    .rank(method='first'))

df
# Out:
#      participant number gender  age  correct hit percentage  \
# 0                     8      f   39                      65
# 1                    16      m   42                      90
# 2                    18      f   31                      90
# 3                    22      f   35                     100
# 4                    27      f   74                      60
# 5                    28      f   61                      80
# 6                    30      m   32                      90
# 7                    33      m   62                      45
# 8                    34      f   33                      80
# 9                    35      f   53                     100
# 10                   38      f   41                      70
# 11                   41      f   36                      90
# 12                   46      f   40                      95
# 13                   49      f   24                      85
# 14                   55      f   32                      75
# ...

# %%
#transformations
df_sorted = df.sort_values(by=['insomnia', 'percent correct'])

df_sorted[['insomnia', 'percent correct', 'rank grouped by insomnia']]
# Out:
#      insomnia  percent correct  rank grouped by insomnia
# 81      False             40.0                       1.0
# 94      False             55.0                       2.0
# 39      False             57.5                       3.0
# 76      False             60.0                       4.0
# 96      False             60.0                       5.0
# 86      False             62.5                       6.0
# 101     False             62.5                       7.0
# 41      False             65.0                       8.0
# 28      False             67.5                       9.0
# 50      False             67.5                      10.0
# 34      False             70.0                      11.0
# 100     False             70.0                      12.0
# 25      False             72.5                      13.0
# 52      False             72.5                      14.0
# 53      False             72.5                      15.0
# ...

# %%
#transformations
df_sorted = df.sort_values(by=['insomnia', 'percent correct'], ascending = False)

df_sorted[['insomnia', 'percent correct', 'rank grouped by insomnia']]
# Out:
#      insomnia  percent correct  rank grouped by insomnia
# 21       True             97.5                      25.0
# 11       True             95.0                      24.0
# 2        True             92.5                      23.0
# 1        True             90.0                      21.0
# 8        True             90.0                      22.0
# 3        True             87.5                      19.0
# 22       True             87.5                      20.0
# 18       True             85.0                      18.0
# 6        True             82.5                      17.0
# 12       True             80.0                      14.0
# 13       True             80.0                      15.0
# 17       True             80.0                      16.0
# 9        True             75.0                      12.0
# 19       True             75.0                      13.0
# 0        True             72.5                      11.0
# ...
